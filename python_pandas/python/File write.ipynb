# %% [markdown]
# Write data to different file formats

# %%
import pandas as pd

# %%
pip install pypyodbc
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
# ...
#   Created wheel for pypyodbc: filename=pypyodbc-1.3.6-py3-none-any.whl size=22870 sha256=db5e78bb2db80fa18177a40f0a47d2545cb7d696e75379c60003ed424df0e37b
#   Stored in directory: c:\users\heman\appdata\local\pip\cache\wheels\cc\0f\d7\04afb4d86f85c4969168e5a366dbf8c17751159188c2c677ed
# Successfully built pypyodbc
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

e = create_engine("mysql+mysqldb://scott:tiger@localhost/test", pool_recycle=3600)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 3
#       1 from sqlalchemy import create_engine
# ----> 3 e = create_engine("mysql+mysqldb://scott:tiger@localhost/test", pool_recycle=3600)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\heman\Desktop\python\venv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File c:\Users\heman\Desktop\python\venv\Lib\site-packages\sqlalchemy\engine\create.py:599, in create_engine(url, **kwargs)
#     597         if k in kwargs:
# ...

# %%
# Define the connection string (for SQL Server)
# Syntax: 'mssql+pyodbc://<username>:<password>@<hostname>/<database_name>?driver=<driver_name>'
connection_string = 'mssql+pyodbc://sa:Hemu@1996@HEMANTHHEMU/DB5L57MB?driver=ODBC Driver 18 for SQL Server'

# Create the SQLAlchemy engine
engine = create_engine(
    "mysql+mysqldb://scott:tiger@localhost/dbname",
    pool_recycle=3600,
    echo=True,
)

# Define your SQL query
sql_query = "SELECT * FROM your_table_name"

# Use pandas to execute the SQL query and load the data into a DataFrame
df = pd.read_sql(sql_query, engine)

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 6
#       3 connection_string = 'mssql+pyodbc://sa:Hemu@1996@HEMANTHHEMU/DB5L57MB?driver=ODBC Driver 18 for SQL Server'
#       5 # Create the SQLAlchemy engine
# ----> 6 engine = create_engine(
#       7     "mysql+mysqldb://scott:tiger@localhost/dbname",
#       8     pool_recycle=3600,
#       9     echo=True,
#      10 )
#      12 # Define your SQL query
#      13 sql_query = "SELECT * FROM your_table_name"
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\heman\Desktop\python\venv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
# ...

# %%
import pypyodbc

# Connection string format for SQL Server
connection_string = "Driver={ODBC Driver 17 for SQL Server};Server=HEMANTHHEMU;Database=DB5L57MB;UID=sa;PWD=Hemu@1996"

# Establish the connection
connection = pypyodbc.connect(connection_string)

sql_query= "select * from Employee"

csv_df = pd.read_sql(sql_query,connection)

csv_df
# Out:
# C:\Users\heman\AppData\Local\Temp\ipykernel_5632\2800911581.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   csv_df = pd.read_sql(sql_query,connection)
#     id           name   salary                   post       location  \
# 0    1    Alice Smith  55000.0      Software Engineer       New York
# 1    2    Bob Johnson  62000.0           Data Analyst       New York
# 2    3  Charlie Brown  70000.0        Project Manager        Chicago
# 3    4   Diana Prince  58000.0            QA Engineer  San Francisco
# 4    5  Edward Norton  75000.0         Data Scientist  San Francisco
# 5    6    Fiona Apple  54000.0           Data Analyst        Chicago
# 6    7  George Martin  66000.0        DevOps Engineer         Austin
# 7    8   Hannah White  63000.0        Project Manager         Austin
# ...
